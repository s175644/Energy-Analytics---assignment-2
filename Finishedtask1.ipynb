# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import pmdarima as pm 
from pmdarima import model_selection 
from sklearn.metrics import mean_squared_error 
from math import sqrt 
import pmdarima as pm 
from pmdarima import model_selection, pipeline, arima
import statsmodels.api as sm 
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import root_mean_squared_error
import matplotlib.dates as mdates

# %% [markdown]
# # Data management

# %%
file_P = os.path.join(os.getcwd(),'Elspotprices2.csv')
df_prices = pd.read_csv(file_P)
df_prices["HourUTC"] = pd.to_datetime(df_prices["HourUTC"])
df_prices = df_prices.loc[(df_prices['PriceArea']=="DK2")][["HourUTC","SpotPriceDKK"]]
df_prices = df_prices.loc[df_prices["HourUTC"].dt.year.isin([2019,2020,2021,2022,2023])]
df_prices = df_prices.reset_index(drop=True)

file_P = os.path.join(os.getcwd(),'ProdConData.csv')
df_data = pd.read_csv(file_P)
df_data["HourUTC"] = pd.to_datetime(df_data["HourUTC"])
df_data = df_data.loc[(df_data['PriceArea']=="DK2")]
df_data = df_data.loc[df_data["HourUTC"].dt.year.isin([2019,2020,2021,2022,2023])]
df_data = df_data.reset_index(drop=True)

# Convert the 'HourUTC' column to datetime if it's not already
df_prices["HourUTC"] = pd.to_datetime(df_prices["HourUTC"])

# Set the start and end dates
start_date = pd.Timestamp('2023-10-01 00:00:00')
end_date = pd.Timestamp('2023-12-31 23:00:00')

#merge dataframes
df_merged = pd.merge(df_prices, df_data, on="HourUTC")

# Filter the data and reset indec
# prices = df_prices
# df_prices = df_prices[(df_prices['HourUTC'] >= start_date) & (df_prices['HourUTC'] <= end_date)]
# df_prices = df_prices.reset_index(drop=True)

# Split data into training and testing sets
data = df_merged[(df_merged['HourUTC'].dt.date >= start_date.date()) & (df_merged['HourUTC'].dt.date <= end_date.date())]
data = data.reset_index(drop=True)

prices = data['SpotPriceDKK'].values

train, test = model_selection.train_test_split(prices, test_size=744) # 744 hours in december

# %% [markdown]
# # Task 1

# %% [markdown]
# #### Plot values of test and train and test seasonality

# %%
n_train = len(train)
n_test = len(test)
n_data = len(data)

plt.figure(figsize=(6, 4), dpi=100)
plt.plot(np.arange(1,n_train+1)/24, train)
plt.plot(np.arange(n_train+1,n_data+1)/24, test)
plt.legend(["Training set", "Testing set"])
plt.grid(alpha=0.25)
plt.tight_layout()
plt.show()


# Plot ACF/PACF plots
fig, ax = plt.subplots(2, 1, figsize=(8, 6))

# Determine lag for ACF/PACF plots
lag = 12*5+1

# Check ACF plot
sm.graphics.tsa.plot_acf(prices["SpotPriceDKK"], title = "ACF", lags=lag, ax=ax[0])

# Check the PACF plot
sm.graphics.tsa.plot_pacf(prices["SpotPriceDKK"], title = "PACF", lags=lag, ax=ax[1])

plt.tight_layout()
plt.show()
# from the previously plot a seasonal pattern is observed, thus we will take the difference of the data with a lag of 12
prices12 = pm.utils.diff(prices["SpotPriceDKK"],12)

# Plot ACF/PACF plots
fig, ax = plt.subplots(2, 1, figsize=(8, 6))

# Check ACF plot
sm.graphics.tsa.plot_acf(prices12, lags=lag, title="ACF Seasonality", ax=ax[0])

# Check the PACF plot
sm.graphics.tsa.plot_pacf(prices12, lags=lag, title="PACF Seasonality", ax=ax[1])

plt.tight_layout()
plt.show()
# Out:
# 744
# 1464

# %% [markdown]
# # Task 1.1

# %% [markdown]
# #### Find ARIMA model

# %%
m_S = pm.auto_arima(train, trace = True, seasonal=True, m = 12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=3.56 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=18125.929, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=17934.451, Time=0.33 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=17927.556, Time=0.86 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=18123.930, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=17926.948, Time=0.11 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=17927.035, Time=0.32 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=2.50 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=17923.456, Time=0.20 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=17923.778, Time=0.62 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=17924.247, Time=0.66 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=3.33 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=17933.776, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=17849.822, Time=0.56 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=17850.572, Time=1.80 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=17850.910, Time=1.95 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=6.57 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=17918.535, Time=0.10 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=17851.684, Time=1.11 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=17851.663, Time=1.17 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=17909.383, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=17853.198, Time=1.60 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=17847.879, Time=0.28 sec
#  ARIMA(2,1,1)(1,0,0)[12]             : AIC=17848.633, Time=0.85 sec
#  ARIMA(2,1,1)(0,0,1)[12]             : AIC=17848.969, Time=0.95 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=inf, Time=2.08 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=17921.456, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=17916.535, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[12]             : AIC=17849.738, Time=0.55 sec
#  ARIMA(2,1,2)(0,0,0)[12]             : AIC=17849.718, Time=0.60 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=17931.775, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=inf, Time=0.57 sec
#  ARIMA(3,1,0)(0,0,0)[12]             : AIC=17907.383, Time=0.08 sec
#  ARIMA(3,1,2)(0,0,0)[12]             : AIC=17851.262, Time=0.68 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[12]
# Total fit time: 35.243 seconds

# %% [markdown]
# ### Forecast

# %%
# Create an empty list for the day ahead forecasts
Forecasts_S = []
Persistence = []


N = int(len(test)/24)
for i in range(N):

    # Generate forecast for the next 24-hour period
    frc_S = m_S.predict(n_periods=24)
    
    # Append the forecast for each hour to the list
    Forecasts_S.extend(frc_S)
    
    # Update the model with new observations 
    m_S.update(test[i])  
    
    #include the Persistence model
    Persistence.extend(prices[len(train)+i*24-24:len(train)+i*24])
   
#Plotting
dates = data["HourUTC"][-744:]
plt.figure(figsize=(6, 4), dpi=100)
plt.plot(dates, test, color = "green")
plt.plot(dates, Forecasts_S)
plt.plot(dates, Persistence)
plt.title("Day ahead predictions for December")
plt.legend(["Actual values", "Forecast", "Persistence"])
plt.ylabel("Spotprice (DKK)")
date_format = mdates.DateFormatter("%d-%m-%Y")
plt.gca().xaxis.set_major_formatter(date_format)
plt.grid(alpha=0.25)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### RMSE

# %%
# Calculate the RMSE for the seasonal persistence forecasts
RMSE_S = sqrt(mean_squared_error(test, Forecasts_S))

RMSE_Persistence = sqrt(mean_squared_error(test, Persistence))

print("RMSE for the seasonal forecast: ", RMSE_S)
print("RMSE for the persistence forecast: ", RMSE_Persistence)
# Out:
# RMSE for the seasonal forecast:  735.5207886043996
# RMSE for the persistence forecast:  248.88782621366917

# %% [markdown]
# # Task 1.2

# %% [markdown]
# #### Deciding variables

# %%
Corr = data.drop(columns=["HourUTC","HourDK","PriceArea"]).corr(method='pearson')
Corr = Corr.round(2)
print(Corr)
# Out:
#                             SpotPriceDKK  CentralPowerMWh  LocalPowerMWh  \
# SpotPriceDKK                        1.00             0.38           0.70
# CentralPowerMWh                     0.38             1.00           0.55
# LocalPowerMWh                       0.70             0.55           1.00
# CommercialPowerMWh                  0.53             0.40           0.56
# LocalPowerSelfConMWh               -0.13             0.07           0.00
# OffshoreWindLt100MW_MWh            -0.39            -0.17          -0.17
# OffshoreWindGe100MW_MWh            -0.45            -0.11          -0.23
# OnshoreWindLt50kW_MWh              -0.59            -0.28          -0.37
# OnshoreWindGe50kW_MWh              -0.61            -0.19          -0.37
# HydroPowerMWh                        NaN              NaN            NaN
# SolarPowerLt10kW_MWh               -0.07            -0.22          -0.13
# SolarPowerGe10Lt40kW_MWh           -0.08            -0.22          -0.14
# SolarPowerGe40kW_MWh               -0.07            -0.23          -0.14
# SolarPowerSelfConMWh               -0.02            -0.18          -0.09
# UnknownProdMWh                     -0.05             0.04           0.04
# ExchangeNO_MWh                       NaN              NaN            NaN
# ExchangeSE_MWh                      0.12            -0.44          -0.09
# ExchangeGE_MWh                      0.06             0.41           0.22
# ExchangeNL_MWh                       NaN              NaN            NaN
# ExchangeGB_MWh                       NaN              NaN            NaN
# ExchangeGreatBelt_MWh               0.38             0.32           0.36
# GrossConsumptionMWh                 0.42             0.40           0.62
# GridLossTransmissionMWh            -0.08             0.11          -0.02
# GridLossInterconnectorsMWh         -0.29            -0.06          -0.41
# GridLossDistributionMWh             0.16             0.59           0.40
# PowerToHeatMWh                     -0.42            -0.17          -0.24
#
#                             CommercialPowerMWh  LocalPowerSelfConMWh  \
# SpotPriceDKK                              0.53                 -0.13
# CentralPowerMWh                           0.40                  0.07
# LocalPowerMWh                             0.56                  0.00
# CommercialPowerMWh                        1.00                 -0.02
# LocalPowerSelfConMWh                     -0.02                  1.00
# OffshoreWindLt100MW_MWh                  -0.14                  0.23
# OffshoreWindGe100MW_MWh                  -0.18                  0.20
# OnshoreWindLt50kW_MWh                    -0.39                  0.37
# OnshoreWindGe50kW_MWh                    -0.33                  0.31
# HydroPowerMWh                              NaN                   NaN
# SolarPowerLt10kW_MWh                     -0.07                  0.71
# SolarPowerGe10Lt40kW_MWh                 -0.09                  0.70
# SolarPowerGe40kW_MWh                     -0.05                  0.70
# SolarPowerSelfConMWh                     -0.04                  0.62
# UnknownProdMWh                           -0.03                  0.10
# ExchangeNO_MWh                             NaN                   NaN
# ExchangeSE_MWh                           -0.04                 -0.19
# ExchangeGE_MWh                            0.10                  0.12
# ExchangeNL_MWh                             NaN                   NaN
# ExchangeGB_MWh                             NaN                   NaN
# ExchangeGreatBelt_MWh                     0.21                 -0.03
# GrossConsumptionMWh                       0.43                  0.30
# GridLossTransmissionMWh                  -0.00                  0.03
# GridLossInterconnectorsMWh               -0.30                 -0.01
# GridLossDistributionMWh                   0.23                  0.31
# PowerToHeatMWh                           -0.22                  0.04
#
#                             OffshoreWindLt100MW_MWh  OffshoreWindGe100MW_MWh  \
# SpotPriceDKK                                  -0.39                    -0.45
# CentralPowerMWh                               -0.17                    -0.11
# LocalPowerMWh                                 -0.17                    -0.23
# CommercialPowerMWh                            -0.14                    -0.18
# LocalPowerSelfConMWh                           0.23                     0.20
# OffshoreWindLt100MW_MWh                        1.00                     0.70
# OffshoreWindGe100MW_MWh                        0.70                     1.00
# OnshoreWindLt50kW_MWh                          0.75                     0.66
# OnshoreWindGe50kW_MWh                          0.75                     0.81
# HydroPowerMWh                                   NaN                      NaN
# SolarPowerLt10kW_MWh                          -0.02                    -0.08
# SolarPowerGe10Lt40kW_MWh                      -0.03                    -0.09
# SolarPowerGe40kW_MWh                          -0.01                    -0.06
# SolarPowerSelfConMWh                          -0.08                    -0.11
# UnknownProdMWh                                 0.15                     0.19
# ExchangeNO_MWh                                  NaN                      NaN
# ExchangeSE_MWh                                -0.31                    -0.41
# ExchangeGE_MWh                                 0.07                     0.08
# ExchangeNL_MWh                                  NaN                      NaN
# ExchangeGB_MWh                                  NaN                      NaN
# ExchangeGreatBelt_MWh                         -0.16                    -0.28
# GrossConsumptionMWh                            0.23                     0.19
# GridLossTransmissionMWh                        0.07                     0.08
# GridLossInterconnectorsMWh                     0.07                     0.17
# GridLossDistributionMWh                        0.22                     0.31
# PowerToHeatMWh                                 0.27                     0.26
#
#                             OnshoreWindLt50kW_MWh  OnshoreWindGe50kW_MWh  \
# SpotPriceDKK                                -0.59                  -0.61
# CentralPowerMWh                             -0.28                  -0.19
# LocalPowerMWh                               -0.37                  -0.37
# CommercialPowerMWh                          -0.39                  -0.33
# LocalPowerSelfConMWh                         0.37                   0.31
# OffshoreWindLt100MW_MWh                      0.75                   0.75
# OffshoreWindGe100MW_MWh                      0.66                   0.81
# OnshoreWindLt50kW_MWh                        1.00                   0.91
# OnshoreWindGe50kW_MWh                        0.91                   1.00
# HydroPowerMWh                                 NaN                    NaN
# SolarPowerLt10kW_MWh                         0.13                  -0.00
# SolarPowerGe10Lt40kW_MWh                     0.13                  -0.01
# SolarPowerGe40kW_MWh                         0.13                   0.01
# SolarPowerSelfConMWh                         0.08                  -0.02
# UnknownProdMWh                               0.18                   0.20
# ExchangeNO_MWh                                NaN                    NaN
# ExchangeSE_MWh                              -0.23                  -0.37
# ExchangeGE_MWh                               0.02                   0.11
# ExchangeNL_MWh                                NaN                    NaN
# ExchangeGB_MWh                                NaN                    NaN
# ExchangeGreatBelt_MWh                       -0.29                  -0.29
# GrossConsumptionMWh                          0.11                   0.13
# GridLossTransmissionMWh                      0.05                   0.02
# GridLossInterconnectorsMWh                   0.14                   0.19
# GridLossDistributionMWh                      0.22                   0.35
# PowerToHeatMWh                               0.26                   0.36
#
#                             HydroPowerMWh  ...  ExchangeSE_MWh  \
# SpotPriceDKK                          NaN  ...            0.12
# CentralPowerMWh                       NaN  ...           -0.44
# LocalPowerMWh                         NaN  ...           -0.09
# CommercialPowerMWh                    NaN  ...           -0.04
# LocalPowerSelfConMWh                  NaN  ...           -0.19
# OffshoreWindLt100MW_MWh               NaN  ...           -0.31
# OffshoreWindGe100MW_MWh               NaN  ...           -0.41
# OnshoreWindLt50kW_MWh                 NaN  ...           -0.23
# OnshoreWindGe50kW_MWh                 NaN  ...           -0.37
# HydroPowerMWh                         NaN  ...             NaN
# SolarPowerLt10kW_MWh                  NaN  ...            0.10
# SolarPowerGe10Lt40kW_MWh              NaN  ...            0.11
# SolarPowerGe40kW_MWh                  NaN  ...            0.10
# SolarPowerSelfConMWh                  NaN  ...            0.13
# UnknownProdMWh                        NaN  ...           -0.10
# ExchangeNO_MWh                        NaN  ...             NaN
# ExchangeSE_MWh                        NaN  ...            1.00
# ExchangeGE_MWh                        NaN  ...           -0.75
# ExchangeNL_MWh                        NaN  ...             NaN
# ExchangeGB_MWh                        NaN  ...             NaN
# ExchangeGreatBelt_MWh                 NaN  ...           -0.52
# GrossConsumptionMWh                   NaN  ...           -0.16
# GridLossTransmissionMWh               NaN  ...           -0.28
# GridLossInterconnectorsMWh            NaN  ...           -0.23
# GridLossDistributionMWh               NaN  ...           -0.40
# PowerToHeatMWh                        NaN  ...           -0.16
#
#                             ExchangeGE_MWh  ExchangeNL_MWh  ExchangeGB_MWh  \
# SpotPriceDKK                          0.06             NaN             NaN
# CentralPowerMWh                       0.41             NaN             NaN
# LocalPowerMWh                         0.22             NaN             NaN
# CommercialPowerMWh                    0.10             NaN             NaN
# LocalPowerSelfConMWh                  0.12             NaN             NaN
# OffshoreWindLt100MW_MWh               0.07             NaN             NaN
# OffshoreWindGe100MW_MWh               0.08             NaN             NaN
# OnshoreWindLt50kW_MWh                 0.02             NaN             NaN
# OnshoreWindGe50kW_MWh                 0.11             NaN             NaN
# HydroPowerMWh                          NaN             NaN             NaN
# SolarPowerLt10kW_MWh                 -0.14             NaN             NaN
# SolarPowerGe10Lt40kW_MWh             -0.15             NaN             NaN
# SolarPowerGe40kW_MWh                 -0.13             NaN             NaN
# SolarPowerSelfConMWh                 -0.10             NaN             NaN
# UnknownProdMWh                        0.04             NaN             NaN
# ExchangeNO_MWh                         NaN             NaN             NaN
# ExchangeSE_MWh                       -0.75             NaN             NaN
# ExchangeGE_MWh                        1.00             NaN             NaN
# ExchangeNL_MWh                         NaN             NaN             NaN
# ExchangeGB_MWh                         NaN             NaN             NaN
# ExchangeGreatBelt_MWh                 0.30             NaN             NaN
# GrossConsumptionMWh                   0.27             NaN             NaN
# GridLossTransmissionMWh               0.22             NaN             NaN
# GridLossInterconnectorsMWh           -0.01             NaN             NaN
# GridLossDistributionMWh               0.42             NaN             NaN
# PowerToHeatMWh                        0.23             NaN             NaN
#
#                             ExchangeGreatBelt_MWh  GrossConsumptionMWh  \
# SpotPriceDKK                                 0.38                 0.42
# CentralPowerMWh                              0.32                 0.40
# LocalPowerMWh                                0.36                 0.62
# CommercialPowerMWh                           0.21                 0.43
# LocalPowerSelfConMWh                        -0.03                 0.30
# OffshoreWindLt100MW_MWh                     -0.16                 0.23
# OffshoreWindGe100MW_MWh                     -0.28                 0.19
# OnshoreWindLt50kW_MWh                       -0.29                 0.11
# OnshoreWindGe50kW_MWh                       -0.29                 0.13
# HydroPowerMWh                                 NaN                  NaN
# SolarPowerLt10kW_MWh                        -0.01                 0.04
# SolarPowerGe10Lt40kW_MWh                    -0.02                 0.02
# SolarPowerGe40kW_MWh                         0.00                 0.10
# SolarPowerSelfConMWh                        -0.01                 0.10
# UnknownProdMWh                              -0.06                 0.12
# ExchangeNO_MWh                                NaN                  NaN
# ExchangeSE_MWh                              -0.52                -0.16
# ExchangeGE_MWh                               0.30                 0.27
# ExchangeNL_MWh                                NaN                  NaN
# ExchangeGB_MWh                                NaN                  NaN
# ExchangeGreatBelt_MWh                        1.00                 0.24
# GrossConsumptionMWh                          0.24                 1.00
# GridLossTransmissionMWh                      0.20                 0.03
# GridLossInterconnectorsMWh                   0.14                -0.21
# GridLossDistributionMWh                      0.12                 0.73
# PowerToHeatMWh                              -0.22                -0.09
#
#                             GridLossTransmissionMWh  \
# SpotPriceDKK                                  -0.08
# CentralPowerMWh                                0.11
# LocalPowerMWh                                 -0.02
# CommercialPowerMWh                            -0.00
# LocalPowerSelfConMWh                           0.03
# OffshoreWindLt100MW_MWh                        0.07
# OffshoreWindGe100MW_MWh                        0.08
# OnshoreWindLt50kW_MWh                          0.05
# OnshoreWindGe50kW_MWh                          0.02
# HydroPowerMWh                                   NaN
# SolarPowerLt10kW_MWh                           0.00
# SolarPowerGe10Lt40kW_MWh                       0.00
# SolarPowerGe40kW_MWh                           0.01
# SolarPowerSelfConMWh                          -0.05
# UnknownProdMWh                                 0.00
# ExchangeNO_MWh                                  NaN
# ExchangeSE_MWh                                -0.28
# ExchangeGE_MWh                                 0.22
# ExchangeNL_MWh                                  NaN
# ExchangeGB_MWh                                  NaN
# ExchangeGreatBelt_MWh                          0.20
# GrossConsumptionMWh                            0.03
# GridLossTransmissionMWh                        1.00
# GridLossInterconnectorsMWh                     0.12
# GridLossDistributionMWh                        0.02
# PowerToHeatMWh                                -0.07
#
#                             GridLossInterconnectorsMWh  \
# SpotPriceDKK                                     -0.29
# CentralPowerMWh                                  -0.06
# LocalPowerMWh                                    -0.41
# CommercialPowerMWh                               -0.30
# LocalPowerSelfConMWh                             -0.01
# OffshoreWindLt100MW_MWh                           0.07
# OffshoreWindGe100MW_MWh                           0.17
# OnshoreWindLt50kW_MWh                             0.14
# OnshoreWindGe50kW_MWh                             0.19
# HydroPowerMWh                                      NaN
# SolarPowerLt10kW_MWh                              0.08
# SolarPowerGe10Lt40kW_MWh                          0.08
# SolarPowerGe40kW_MWh                              0.09
# SolarPowerSelfConMWh                             -0.01
# UnknownProdMWh                                    0.05
# ExchangeNO_MWh                                     NaN
# ExchangeSE_MWh                                   -0.23
# ExchangeGE_MWh                                   -0.01
# ExchangeNL_MWh                                     NaN
# ExchangeGB_MWh                                     NaN
# ExchangeGreatBelt_MWh                             0.14
# GrossConsumptionMWh                              -0.21
# GridLossTransmissionMWh                           0.12
# GridLossInterconnectorsMWh                        1.00
# GridLossDistributionMWh                          -0.10
# PowerToHeatMWh                                   -0.05
#
#                             GridLossDistributionMWh  PowerToHeatMWh
# SpotPriceDKK                                   0.16           -0.42
# CentralPowerMWh                                0.59           -0.17
# LocalPowerMWh                                  0.40           -0.24
# CommercialPowerMWh                             0.23           -0.22
# LocalPowerSelfConMWh                           0.31            0.04
# OffshoreWindLt100MW_MWh                        0.22            0.27
# OffshoreWindGe100MW_MWh                        0.31            0.26
# OnshoreWindLt50kW_MWh                          0.22            0.26
# OnshoreWindGe50kW_MWh                          0.35            0.36
# HydroPowerMWh                                   NaN             NaN
# SolarPowerLt10kW_MWh                          -0.11           -0.09
# SolarPowerGe10Lt40kW_MWh                      -0.12           -0.09
# SolarPowerGe40kW_MWh                          -0.09           -0.10
# SolarPowerSelfConMWh                          -0.04           -0.06
# UnknownProdMWh                                 0.21            0.02
# ExchangeNO_MWh                                  NaN             NaN
# ExchangeSE_MWh                                -0.40           -0.16
# ExchangeGE_MWh                                 0.42            0.23
# ExchangeNL_MWh                                  NaN             NaN
# ExchangeGB_MWh                                  NaN             NaN
# ExchangeGreatBelt_MWh                          0.12           -0.22
# GrossConsumptionMWh                            0.73           -0.09
# GridLossTransmissionMWh                        0.02           -0.07
# GridLossInterconnectorsMWh                    -0.10           -0.05
# GridLossDistributionMWh                        1.00            0.08
# PowerToHeatMWh                                 0.08            1.00
#
# [26 rows x 26 columns]

# %% [markdown]
# #### Model

# %%
n_train = len(train)
n_test = len(test)
n_data = len(data)
# Get the training/testing datasets of the predictors
X_train, X_test = model_selection.train_test_split(data[["CentralPowerMWh","LocalPowerMWh"]], test_size=744)

# Define X_train_ar 
n = n_train
X_train_ar = np.column_stack([np.arange(1, n+1), X_train])

#Use pipeline to create model
pipe = pipeline.Pipeline([
    ("fourier", pm.preprocessing.FourierFeaturizer(m=24, k = 12)),
    ("arima", arima.AutoARIMA(stepwise=False, trace=1, error_action="ignore",
                              seasonal=False, maxiter=20, 
                              suppress_warnings=True))])

pipe.fit(train, X = X_train_ar)
# Out:
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=20635.823, Time=4.00 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=19497.319, Time=2.24 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=19160.777, Time=2.65 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=18845.487, Time=3.22 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=18774.515, Time=3.25 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=18662.174, Time=3.78 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=2.18 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=17672.245, Time=2.74 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=17677.229, Time=3.48 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=17725.473, Time=3.52 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=17705.114, Time=3.83 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=17641.005, Time=2.52 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=17695.262, Time=2.97 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=17785.436, Time=3.20 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=17769.954, Time=3.60 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=17684.842, Time=3.44 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=17754.785, Time=3.00 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=17773.529, Time=3.33 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=17737.508, Time=3.37 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=17766.722, Time=3.25 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=17747.850, Time=4.15 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 67.693 seconds
# Pipeline(steps=[('fourier', FourierFeaturizer(k=12, m=24)),
#                 ('arima',
#                  AutoARIMA(error_action='ignore', maxiter=20, seasonal=False,
#                            stepwise=False, trace=1))])

# %% [markdown]
#  #### Forecast

# %%
#Create empty arrays

rolling_forecast = []
Persistence   = []

dataset = data['SpotPriceDKK']

N = int(len(test)/24)

for i in range(N):

    # Create X_f for the forecasting period
    X_f = np.column_stack([np.arange(1, 24+1), 
                           X_test[i*24:(i+1)*24]])

    forecast = pipe.predict(n_periods=24, X = X_f)
    
    rolling_forecast.extend(forecast)

    pipe.update(test[i*24:(i+1)*24], X = X_f)
    Persistence.extend(dataset[len(train)+i*24-24:len(train)+(i+1)*24-24])
    

#Plotting
rolling_forecast = [0 if x < 0 else x for x in rolling_forecast]

plt.figure(figsize=(6, 4), dpi=100)

plt.plot(dates, rolling_forecast, color = "blue")
plt.plot(dates, Persistence, color = "darkorange")
plt.plot(dates, test, color = "green")
plt.legend(["Forecast","Persistence" , "Actual values"], loc = "upper right")
plt.grid(alpha=0.25)
plt.ylabel("Spotprice (DKK)")
date_format = mdates.DateFormatter("%d-%m-%Y")
plt.gca().xaxis.set_major_formatter(date_format)
plt.xticks(rotation=45)

plt.show()
plt.tight_layout()

RMSE_P24 = root_mean_squared_error(Persistence, test)
RMSE_F = root_mean_squared_error(rolling_forecast, test)

print("RMSE for daily persistence: ", RMSE_P24)
print("RMSE for forecasts: ", RMSE_F)
# Out:
# RMSE for daily persistence:  248.88782621366917
# RMSE for forecasts:  260.6724802121973

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Task 2.1

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df_prices['SpotPriceDKK'] = scaler.fit_transform(df_prices[['SpotPriceDKK']])

# Define a function to create sequences
def create_sequences(data, sequence_length):
    xs, ys = [], []
    data = data.values  # Ensure 'data' is a NumPy array
    for i in range(len(data) - sequence_length):
        x = data[i:(i + sequence_length)]
        y = data[i + sequence_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 24  # Using 24 hours of data to predict the next hour
X, y = create_sequences(df_prices['SpotPriceDKK'], sequence_length)

# Splitting data into training and testing sets
train_size = int(len(X) * 0.9)  # 90% for training
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# X_train and X_test for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Building the LSTM model
model = Sequential([
    LSTM(50, input_shape=(X_train.shape[1], 1), return_sequences=True),  
    LSTM(50, return_sequences=False),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Training the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model using RMSE
predictions = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print("Test RMSE: ", rmse)

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Model Loss Progression During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/30
# c:\Users\willi\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0262 - val_loss: 0.0038
# Epoch 2/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0085 - val_loss: 0.0024
# Epoch 3/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0073 - val_loss: 0.0012
# Epoch 4/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 5/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0052 - val_loss: 9.6385e-04
# Epoch 6/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 7/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0036 - val_loss: 7.8150e-04
# Epoch 8/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0027 - val_loss: 7.8706e-04
# Epoch 9/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 5.2659e-04
# Epoch 10/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0023 - val_loss: 7.4856e-04
# Epoch 11/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - val_loss: 5.7049e-04
# Epoch 12/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - val_loss: 5.6368e-04
# Epoch 13/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - val_loss: 5.1577e-04
# Epoch 14/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 3.9552e-04
# Epoch 15/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - val_loss: 7.5337e-04
# Epoch 16/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0023 - val_loss: 5.7255e-04
# Epoch 17/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 4.0078e-04
# Epoch 18/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - val_loss: 6.2355e-04
# Epoch 19/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 4.5078e-04
# Epoch 20/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015 - val_loss: 3.7467e-04
# Epoch 21/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 6.4490e-04
# Epoch 22/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - val_loss: 3.5849e-04
# Epoch 23/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020 - val_loss: 7.4507e-04
# Epoch 24/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - val_loss: 3.9460e-04
# Epoch 25/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - val_loss: 3.7663e-04
# Epoch 26/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015 - val_loss: 3.8126e-04
# Epoch 27/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - val_loss: 4.1643e-04
# Epoch 28/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0020 - val_loss: 4.7976e-04
# Epoch 29/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0016 - val_loss: 4.8927e-04
# Epoch 30/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018 - val_loss: 4.2551e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Test RMSE:  0.02081836000757145

# %% [markdown]
# ## Task 2.2

# %%
# Adjusting column names according to the data
df_data= df_data[df_data['PriceArea'] == 'DK2']

df_data['DayOfWeek'] = df_data['HourUTC'].dt.dayofweek  # Adding day of the week as an exogenous variable
df_data = df_data[['HourUTC', 'OffshoreWindGe100MW_MWh', 'OnshoreWindGe50kW_MWh', 'SolarPowerGe40kW_MWh', 'DayOfWeek']]

df_merged = pd.merge(df_prices, df_data, on='HourUTC')

# Normalizng
scaler = MinMaxScaler(feature_range=(0, 1))
features = ['SpotPriceDKK', 'OffshoreWindGe100MW_MWh', 'OnshoreWindGe50kW_MWh', 'SolarPowerGe40kW_MWh', 'DayOfWeek']

df_merged[features] = scaler.fit_transform(df_merged[features])

# Define a function to create sequences
def create_sequences(data, sequence_length):
    xs, ys = [], []
    data = data.to_numpy()  # Convert DataFrame to numpy array for processing
    for i in range(len(data) - sequence_length):
        x = data[i:(i + sequence_length), :]
        y = data[i + sequence_length, 0]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# Creating sequence
sequence_length = 24
X, y = create_sequences(df_merged[features], sequence_length)

# Splitting data into training and testing sets
train_size = int(len(X) * 0.9)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Checing the input shape is correctly specified
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], len(features)))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], len(features)))

# Rebuild the LSTM model
model = Sequential([
    LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    LSTM(50),
    Dense(1)
])
model.compile(optimizer='adam', loss='mean_squared_error')

# Training the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Predict and calculate RMSE
predictions = model.predict(X_test)
rmse_exogenous = np.sqrt(mean_squared_error(y_test, predictions))
print("Test RMSE with Exogenous Variables: ", rmse_exogenous)

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Model Loss Progression During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/30
# c:\Users\willi\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0237 - val_loss: 0.0030
# Epoch 2/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0088 - val_loss: 0.0033
# Epoch 3/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0081 - val_loss: 0.0021
# Epoch 4/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0072 - val_loss: 0.0018
# Epoch 5/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0051 - val_loss: 0.0011
# Epoch 6/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0043 - val_loss: 0.0011
# Epoch 7/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - val_loss: 9.3984e-04
# Epoch 8/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0027 - val_loss: 8.4561e-04
# Epoch 9/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025 - val_loss: 5.5689e-04
# Epoch 10/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 11/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 12/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 5.1573e-04
# Epoch 13/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 8.4008e-04
# Epoch 14/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - val_loss: 5.7462e-04
# Epoch 15/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 3.8505e-04
# Epoch 16/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 17/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023 - val_loss: 4.6175e-04
# Epoch 18/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017 - val_loss: 5.2124e-04
# Epoch 19/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014 - val_loss: 8.1427e-04
# Epoch 20/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - val_loss: 5.8848e-04
# Epoch 21/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - val_loss: 3.7810e-04
# Epoch 22/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0016 - val_loss: 4.8918e-04
# Epoch 23/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - val_loss: 3.6348e-04
# Epoch 24/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 9.3792e-04
# Epoch 25/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023 - val_loss: 4.6449e-04
# Epoch 26/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014 - val_loss: 3.7131e-04
# Epoch 27/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0014 - val_loss: 3.7007e-04
# Epoch 28/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - val_loss: 3.9500e-04
# Epoch 29/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015 - val_loss: 3.9875e-04
# Epoch 30/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - val_loss: 3.7638e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Test RMSE with Exogenous Variables:  0.01955857535931706

# %% [markdown]
# # Task 4

# %% [markdown]
# ### Combine the forecasting tool that predicts for the next 24 hours you developed with the optimization tool for the optimal bidding strategy for batteries you developed in Assignment 1, and calculate the total profits for the whole month of December 2023.

# %%
##  The battery has a 50% SOC at the start of your simulation (on December 1st).
##  Each day you optimize the schedule of the battery between 00:00 and for the next 24 hours.
##  You buy and sell energy at the spot price (do not consider any taxes or tariffs).

##  You can decide what your state of charge constraint at the end of each daily optimization is.
##  Remember that the final SOC of day N is the starting SOC of day N+1! Mind that on the first
##  day the SOC is set to 50% (initial SOC on December 1) and you should choose the same strategy
##  for the whole period.

##  The choice of the final SOC constraint must be justified using your training dataset and not your
##  testing dataset! You should design a strategy based on available data and not tailor your strategy
##  based on the testing dataset!


params = {
    'Pmax': 5, #Max charging capacity 1 MW
    'n_c': 0.95, #Charging effiency
    'n_d': 0.95, #Decharging effiency
    'Cmax': 10 #Max 2 MWh storage
}

params['C_0'] = 0.5 * params['Cmax'] #SOC at start
params['C_n'] = 0.5 * params['Cmax'] #SOC at end

# %% [markdown]
# ## Task 4.1

# %% [markdown]
# ### Calculate the profits you achieve during the testing dataset by using the bidding model from Assignment 1 and perfect knowledge of prices (you performed this task in Assignment 1)

# %%
#Convert prices to DKK/kWh
df_prices["SpotPriceDKK"] = df_prices["SpotPriceDKK"]/1000

## import the cvxpy library
import cvxpy as cp

## Define the optimizer function

def Optimizer(params, p):

    import cvxpy as cp

    n = len(p)
    p_c = cp.Variable(n)
    p_d = cp.Variable(n)
    X   = cp.Variable(n)
    profit = cp.sum(p_d@p - p_c@p)
    
    constraints = [p_c >= 0, 
                   p_d >= 0, 
                   p_c <= params['Pmax'], 
                   p_d <= params['Pmax']]
    constraints += [X >= 0, X <= params['Cmax']]
    constraints += [X[0]==params['C_0'] + p_c[0]*params['n_c'] - p_d[0]/params['n_d']]
    
    constraints += [X[1:] == X[:-1] + p_c[1:]*params['n_c'] - p_d[1:]/params['n_d']]
    
    constraints += [X[n-1]>=params['C_n']]
    
    problem = cp.Problem(cp.Maximize(profit), constraints)
    problem.solve(solver=cp.ECOS)
    
    return profit.value, p_c.value, p_d.value, X.value

# Convert prices to DKK/kWh
test = test/1000
profitOpt, p_cOpt, p_dOpt, XOpt = Optimizer(params, test)

print("Profit using battery in december using actual values is:", profitOpt, ",DKK")
# Out:
# Profit using battery in december using actual values is: 137.91642501644026 ,DKK

# %% [markdown]
# ### Next, use the forecasting model you developed and has the highest accuracy (ARIMA or LSTM) for day-ahead prediction, and use the forecasted prices instead of the actual ones to bid.

# %%
## We use ARIMA model m_S to predict the spot prices for the month of December 2023 and calculate the profit

# Convert prices to DKK/kWh
Forecasts_S = np.array(Forecasts_S)
Forecasts_S = Forecasts_S/1000

profitOpt, p_cOpt, p_dOpt, XOpt = Optimizer(params, Forecasts_S)
print("Profit using battery in december using forecasted values is:", profitOpt, ",DKK")

## Now also use the LSTM model and compare the results

# .............................................
# Out:
# Profit using battery in december using forecasted values is: 41.83857942094062 ,DKK

# %% [markdown]
# ### Compare the profits you achieve with your forecasting model with the ones you achieve with perfect price knowledge. What do you observe?

# %%
print("Ádd something here")
# Out:
# Ádd something here

# %% [markdown]
# ## Task 4.2

# %% [markdown]
# ### Use the persistence model for day-ahead predictions you established in task 1.1 to forecast electricity prices, and use those to calculate your profits from optimizing the battery.

# %%
## Now we use the persistence data to predict the profit from optimizing the battery

# Convert prices to DKK/kWh
CentralPersistence = np.array(CentralPersistence)
CentralPersistence = CentralPersistence/1000

profitOpt, p_cOpt, p_dOpt, XOpt = Optimizer(params, CentralPersistence)
print("Profit using battery in december using persistence forecast is:", profitOpt, ",DKK")
# Out:
# Profit using battery in december using persistence forecast is: 542.4504676160522 ,DKK

# %% [markdown]
# ### Compare the profits you obtain from persistence forecasting with the profits you calculated in task 4.1 (perfect knowledge and forecasts via ARIMA or LSTM). Discuss the results and what is the added value of your forecaster, compared to simply using persistence.

# %%
print("Add something here")
# Out:
# Add something here

# %% [markdown]
# ## Task 4.3

# %% [markdown]
# ### Do this in overleaf

# %% [markdown]
# ##
